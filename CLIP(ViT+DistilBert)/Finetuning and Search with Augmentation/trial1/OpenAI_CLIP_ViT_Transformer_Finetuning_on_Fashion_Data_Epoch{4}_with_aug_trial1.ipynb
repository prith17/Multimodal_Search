# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1. Installing Dependencies

# %%
# !pip install timm
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.15.2+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0)
# Collecting huggingface-hub (from timm)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.2 MB/s eta 0:00:00
# Collecting safetensors (from timm)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, timm
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 timm-0.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 101.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.29.2

# %% [markdown]
# #2. Importing required libraries

# %%
import os
import cv2
import gc
import numpy as np
import pandas as pd
import itertools
from tqdm.autonotebook import tqdm
import albumentations as A
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.nn.functional as F
import timm
from transformers import DistilBertModel, DistilBertConfig, DistilBertTokenizer
# Out:
# <ipython-input-3-2540d8c9d86b>:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# #3. Config

# %%
class CFG:
    debug = False
    image_path = "/content/fashion-product-images-small/images"
    captions_path = "/content"
    batch_size = 64
    num_workers = 0
    head_lr = 1e-3
    image_encoder_lr = 1e-4
    text_encoder_lr = 1e-5
    weight_decay = 1e-3
    patience = 1
    factor = 0.8
    epochs = 4
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model_name = 'vit_base_patch32_clip_224.openai'
    image_embedding = 768
    text_encoder_model = "distilbert-base-uncased"
    text_embedding = 768
    text_tokenizer = "distilbert-base-uncased"
    max_length = 200

    pretrained = True # for both image encoder and text encoder
    trainable = True # for both image encoder and text encoder
    temperature = 1.0

    # image size
    size = 224

    # for projection head; used for both image and text encoders
    num_projection_layers = 1
    projection_dim = 512
    dropout = 0.1

# %% [markdown]
# #4. Model Comparision

# %%
model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True)
model
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Downloading model.safetensors:   0%|          | 0.00/114M [00:00<?, ?B/s]
# SwinTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#   )
#   (layers): Sequential(
#     (0): SwinTransformerStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): Identity()
#           (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=96, out_features=288, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=96, out_features=96, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.009)
#           (norm2): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (1): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=384, out_features=192, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.018)
#           (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.027)
#           (norm2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (2): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=768, out_features=384, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.036)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.045)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.055)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.064)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.073)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): SwinTransformerBlock(
#           (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.082)
#           (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (3): SwinTransformerStage(
#       (downsample): PatchMerging(
#         (norm): LayerNorm((1536,), eps=1e-05, elementwise_affine=True)
#         (reduction): Linear(in_features=1536, out_features=768, bias=False)
#       )
#       (blocks): Sequential(
#         (0): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.091)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlock(
#           (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): WindowAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (attn_drop): Dropout(p=0.0, inplace=False)
#             (proj): Linear(in_features=768, out_features=768, bias=True)
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#           (drop_path): DropPath(drop_prob=0.100)
#           (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Identity())
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#     (flatten): Identity()
#   )
# )

# %%
model=timm.create_model("vit_base_patch32_clip_224.openai",pretrained=True)
model
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (patch_drop): Identity()
#   (norm_pre): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (fc_norm): Identity()
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=768, out_features=512, bias=True)
# )

# %%
model=timm.create_model("resnet50",pretrained=True)
model
# Out:
# Downloading model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# #5. Loading Dataset

# %%
# !pip install kaggle --upgrade
os.environ['KAGGLE_USERNAME'] = "prith17"
os.environ['KAGGLE_KEY'] = "e2f24267509e5acdcaf70a4be819f4c1"

### For Flickr 8k
# !kaggle datasets download -d paramaggarwal/fashion-product-images-small
# !unzip flickr8k.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)
# Downloading fashion-product-images-small.zip to /content
# 100% 564M/565M [00:27<00:00, 22.9MB/s]
# 100% 565M/565M [00:27<00:00, 21.5MB/s]

# %%
# !unzip /content/fashion-product-images-small.zip -d /content/fashion-product-images-small
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/fashion-product-images-small/myntradataset/images/5813.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58131.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58132.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58133.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58135.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58136.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58137.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58138.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58139.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5814.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58140.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58141.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58143.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58144.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58145.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58146.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58147.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58148.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58149.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5815.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58150.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58151.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58152.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58153.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58154.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58155.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58156.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58157.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58158.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58159.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5816.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58160.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58161.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58162.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58163.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58164.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58165.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58166.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58167.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58168.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58169.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5817.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58170.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58171.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58172.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58173.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58174.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58175.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58176.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58177.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58178.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58179.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5818.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58180.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58181.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58182.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58183.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58184.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58185.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58186.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58187.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58188.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58189.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5819.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58190.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58191.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58194.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58195.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58196.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5820.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58200.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58201.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58202.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58203.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58204.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58205.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58206.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58207.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58208.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58209.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5821.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58210.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58211.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58212.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58213.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58214.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58215.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58216.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58218.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5822.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58220.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58222.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58225.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58226.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58227.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58229.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5823.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58231.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58232.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58233.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58234.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58235.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58236.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58237.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58238.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58239.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5824.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58240.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58241.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58242.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58243.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58244.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58245.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58246.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58247.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58248.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58249.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5825.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58250.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58251.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58252.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58253.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58254.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58255.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58256.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58257.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58258.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58259.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5826.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58260.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58261.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58262.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58263.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58264.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58265.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58266.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58267.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58268.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58269.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5827.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58270.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58271.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58272.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58273.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58274.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58275.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58276.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58277.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58278.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58279.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5828.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58280.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58281.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58282.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58283.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58284.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58286.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5829.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58291.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58292.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58293.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58294.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58295.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58296.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58297.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58298.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58299.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5830.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58300.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58301.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58304.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58305.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58306.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58307.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58308.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58309.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5831.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58310.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58311.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58312.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58313.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58314.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58315.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58316.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58317.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58318.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58319.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5832.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58320.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58321.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58322.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58323.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58324.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58325.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58326.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58327.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58328.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58329.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5833.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58330.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58331.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58332.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58333.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58334.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58335.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58336.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58337.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58338.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58339.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5834.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58340.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58349.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5835.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58351.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58357.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58358.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5836.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5837.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58372.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58375.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5838.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58381.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58385.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5839.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58394.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58395.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5840.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5841.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58411.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58418.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5842.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58425.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5843.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58439.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5844.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58444.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58445.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58446.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58447.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58448.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58449.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5845.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58450.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58451.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58452.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58453.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58454.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58455.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58456.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58458.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58459.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5846.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58460.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58463.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58464.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58465.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58466.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58467.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58468.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5847.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58470.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58471.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58472.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58473.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58474.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58475.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58476.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58477.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58478.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58479.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5848.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58480.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58481.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58482.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58483.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58484.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58485.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58486.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58487.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58488.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58489.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5849.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58490.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58491.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58492.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58493.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58494.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58495.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58496.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58497.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58498.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58499.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5850.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58500.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58501.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58502.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58503.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58504.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58505.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58506.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58507.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58508.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58509.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5851.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58510.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58511.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58512.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58513.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58514.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58515.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58516.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58517.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58518.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58519.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5852.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58520.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58521.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58522.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58523.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58524.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58525.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58526.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58527.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58528.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58529.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5853.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58530.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58531.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58532.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58533.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58534.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58535.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58536.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58537.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58538.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58539.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5854.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58540.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58541.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58542.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58543.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58544.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58545.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58546.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58547.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58548.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58549.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5855.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58550.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58551.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58552.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58553.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58555.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58559.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5856.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58560.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58561.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58562.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58563.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58565.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58566.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58567.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58569.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5857.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58570.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58571.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58573.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58574.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58576.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58577.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5858.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58581.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58586.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58588.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58589.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5859.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58590.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58591.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5860.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58600.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58603.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58605.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58606.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58607.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58608.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58609.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5861.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58610.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58611.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58612.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58614.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58615.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58616.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58618.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58619.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5862.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58620.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58621.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58622.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58624.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58625.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58626.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58627.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58628.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58629.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5863.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58634.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58635.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58636.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58637.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58638.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58639.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5864.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58640.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58641.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58642.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58643.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58644.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58645.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58646.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58647.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58648.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5865.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58652.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58653.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58654.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58655.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58656.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58657.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58658.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58659.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5866.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58660.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58661.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58662.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58663.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58664.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58666.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58667.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58668.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58669.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5867.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58670.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58671.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58672.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58673.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58674.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58675.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58676.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58677.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58678.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5868.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58680.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58681.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58682.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58683.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58684.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58685.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58686.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58687.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58689.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5869.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58690.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58691.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58692.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58693.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58694.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58695.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58696.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58698.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5870.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58700.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58701.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58702.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58703.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5871.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58718.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58719.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58720.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58722.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58723.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58724.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58725.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58726.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58727.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58728.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58729.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5873.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58730.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58731.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58732.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58734.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58735.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58736.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58737.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58738.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5874.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58740.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58741.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58742.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58743.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58744.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58745.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5875.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5876.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58765.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5877.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58770.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5878.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5879.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58793.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58794.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58795.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58796.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58797.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58798.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58800.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58801.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58802.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58805.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58807.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58808.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58809.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5881.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58810.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58815.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58816.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58817.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58818.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58819.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5882.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58820.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58821.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58822.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58823.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58825.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58827.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58828.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58829.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5883.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58830.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58831.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58832.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58833.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58834.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58835.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58836.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58837.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58838.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58839.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5884.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58840.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58841.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58842.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58843.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58844.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58845.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58846.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58847.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58848.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58849.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/5885.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58850.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58851.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58852.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58853.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58854.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58855.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58856.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58857.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/58858.jpg
# ...
#   inflating: /content/fashion-product-images-small/myntradataset/images/9771.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9772.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9773.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9774.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9775.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9776.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9777.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9778.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9779.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9780.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9781.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9782.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9783.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9784.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9785.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9788.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9789.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9790.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9791.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9792.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9793.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9794.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9795.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9796.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9797.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9798.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9799.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9800.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9801.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9802.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9803.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9804.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9805.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9806.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9807.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9808.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9809.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9810.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9812.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9814.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9815.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9816.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9817.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9818.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9819.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9820.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9821.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9822.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9823.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9824.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9825.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9826.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9827.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9828.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9829.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9830.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9831.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9832.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9833.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9834.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9835.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9836.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9839.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9840.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9841.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9842.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9852.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9854.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9856.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9857.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9858.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9859.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9860.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9862.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9863.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9864.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9865.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9866.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9867.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9868.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9869.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9870.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9871.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9874.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9875.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9876.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9877.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9878.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9879.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9880.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9881.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9882.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9883.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9884.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9885.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9892.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9894.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9900.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9901.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9902.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9903.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9904.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9906.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9907.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9908.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9909.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9910.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9911.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9912.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9913.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9914.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9915.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9916.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9917.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9918.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9919.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9920.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9921.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9922.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9923.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9924.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9925.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9926.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9927.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9929.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9931.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9932.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9933.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9934.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9935.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9937.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9938.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9940.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9941.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9942.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9943.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9944.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9945.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9946.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9947.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9948.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9949.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9950.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9951.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9952.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9953.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9954.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9955.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9956.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9957.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9958.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9959.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9960.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9961.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9962.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9963.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9964.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9965.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9966.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9967.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9968.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9969.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9970.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9971.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9972.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9973.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9974.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9975.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9976.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9977.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9978.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9980.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9981.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9982.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9983.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9984.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9985.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9986.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9987.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9988.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9989.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9990.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9991.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9992.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9993.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9994.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9995.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9996.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9997.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9998.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/images/9999.jpg
#   inflating: /content/fashion-product-images-small/myntradataset/styles.csv
#   inflating: /content/fashion-product-images-small/styles.csv

# %% [markdown]
# #6. Some pre-processing

# %%
df = pd.read_csv("/content/fashion-product-images-small/styles.csv",on_bad_lines='skip')
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
df['image'] = df['id'].astype(str) + '.jpg'

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# 1           Blue  Summer  2012.0  Casual
# 2         Silver  Winter  2016.0  Casual
# 3          Black    Fall  2011.0  Casual
# 4           Grey  Summer  2012.0  Casual
# ...          ...     ...     ...     ...
# 44419      White  Summer  2013.0  Casual
# 44420        Red  Summer  2011.0  Casual
# 44421       Blue    Fall  2011.0  Casual
# 44422       Blue  Spring  2017.0  Casual
# 44423       Pink  Winter  2016.0  Casual
#
#                                     productDisplayName      image
# 0                     Turtle Check Men Navy Blue Shirt  15970.jpg
# 1                   Peter England Men Party Blue Jeans  39386.jpg
# 2                             Titan Women Silver Watch  59263.jpg
# 3        Manchester United Men Solid Black Track Pants  21379.jpg
# 4                                Puma Men Grey T-shirt  53759.jpg
# ...                                                ...        ...
# 44419                        Gas Men Caddy Casual Shoe  17036.jpg
# 44420               Lotto Men's Soccer Track Flip Flop   6461.jpg
# 44421             Puma Men Graphic Stellar Blue Tshirt  18842.jpg
# 44422                   Rasasi Women Blue Lady Perfume  46694.jpg
# 44423  Fossil Women Pink Dial Chronograph Watch ES3050  51623.jpg
#
# [44424 rows x 11 columns]

# %%
import os

# Define the image path
image_path = CFG.image_path

# Function to check if the file exists
def file_exists(filename):
    file_path = os.path.join(image_path, filename)
    return os.path.exists(file_path)

# Apply the file_exists function to the 'image' column
df = df[df['image'].apply(file_exists)]

# %%
df
# Out:
#           id gender masterCategory subCategory            articleType  \
# 0      15970    Men        Apparel     Topwear                 Shirts
# 1      39386    Men        Apparel  Bottomwear                  Jeans
# 2      59263  Women    Accessories     Watches                Watches
# 3      21379    Men        Apparel  Bottomwear            Track Pants
# 4      53759    Men        Apparel     Topwear                Tshirts
# ...      ...    ...            ...         ...                    ...
# 44419  17036    Men       Footwear       Shoes           Casual Shoes
# 44420   6461    Men       Footwear  Flip Flops             Flip Flops
# 44421  18842    Men        Apparel     Topwear                Tshirts
# 44422  46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44423  51623  Women    Accessories     Watches                Watches
#
#       baseColour  season    year   usage  \
# 0      Navy Blue    Fall  2011.0  Casual
# 1           Blue  Summer  2012.0  Casual
# 2         Silver  Winter  2016.0  Casual
# 3          Black    Fall  2011.0  Casual
# 4           Grey  Summer  2012.0  Casual
# ...          ...     ...     ...     ...
# 44419      White  Summer  2013.0  Casual
# 44420        Red  Summer  2011.0  Casual
# 44421       Blue    Fall  2011.0  Casual
# 44422       Blue  Spring  2017.0  Casual
# 44423       Pink  Winter  2016.0  Casual
#
#                                     productDisplayName      image
# 0                     Turtle Check Men Navy Blue Shirt  15970.jpg
# 1                   Peter England Men Party Blue Jeans  39386.jpg
# 2                             Titan Women Silver Watch  59263.jpg
# 3        Manchester United Men Solid Black Track Pants  21379.jpg
# 4                                Puma Men Grey T-shirt  53759.jpg
# ...                                                ...        ...
# 44419                        Gas Men Caddy Casual Shoe  17036.jpg
# 44420               Lotto Men's Soccer Track Flip Flop   6461.jpg
# 44421             Puma Men Graphic Stellar Blue Tshirt  18842.jpg
# 44422                   Rasasi Women Blue Lady Perfume  46694.jpg
# 44423  Fossil Women Pink Dial Chronograph Watch ES3050  51623.jpg
#
# [44419 rows x 11 columns]

# %%
df.head()
df.to_csv("captions.csv", index=False)
df = pd.read_csv("captions.csv")

# %%
df['image'] = df['image'].astype(str)

# %%
df['productDisplayName']
# Out:
# 0                       Turtle Check Men Navy Blue Shirt
# 1                     Peter England Men Party Blue Jeans
# 2                               Titan Women Silver Watch
# 3          Manchester United Men Solid Black Track Pants
# 4                                  Puma Men Grey T-shirt
#                               ...
# 44414                          Gas Men Caddy Casual Shoe
# 44415                 Lotto Men's Soccer Track Flip Flop
# 44416               Puma Men Graphic Stellar Blue Tshirt
# 44417                     Rasasi Women Blue Lady Perfume
# 44418    Fossil Women Pink Dial Chronograph Watch ES3050
# Name: productDisplayName, Length: 44419, dtype: object

# %% [markdown]
# ##7. Utils

# %%
class AvgMeter:
    def __init__(self, name="Metric"):
        self.name = name
        self.reset()

    def reset(self):
        self.avg, self.sum, self.count = [0] * 3

    def update(self, val, count=1):
        self.count += count
        self.sum += val * count
        self.avg = self.sum / self.count

    def __repr__(self):
        text = f"{self.name}: {self.avg:.4f}"
        return text

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group["lr"]

# %% [markdown]
# #8. Setting up required components

# %% [markdown]
# ##8.1 CLIP Dataset

# %%
import pandas as pd
from PIL import Image 
import torchvision.transforms as transforms

class CLIP_Dataset(torch.utils.data.Dataset):
    def __init__(self, image_filenames, captions, tokenizer):
        self.image_filenames = image_filenames
        self.captions = captions
        self.encoded_captions = tokenizer(
            captions, padding=True, truncation=True, max_length=CFG.max_length
        )

        self.transform = transforms.Compose([
            transforms.Resize(256),
            transforms.RandomCrop(128),
            transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
            transforms.RandomHorizontalFlip(p=1),
            transforms.RandomVerticalFlip(p=1),
            transforms.RandomResizedCrop(224, scale=(0.08, 1.0), ratio=(0.75, 1.333)),
            transforms.CenterCrop(150),
            transforms.Resize(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __getitem__(self, idx):
        item = {
            key: torch.tensor(values[idx])
            for key, values in self.encoded_captions.items()
        }

        try:
            image = Image.open(f"{CFG.image_path}/{self.image_filenames[idx]}", mode='r')
            image = image.convert("RGB")
            # image = np.array(image)
            image = self.transform(image)
            item['image'] = torch.tensor(image)
            item['caption'] = self.captions[idx]
        except FileNotFoundError:
            return None

        return item


    def __len__(self):
        return len(self.captions)

# %% [markdown]
# ##8.2 Image Encoder

# %%
class ImageEncoder(nn.Module):
    """
    Encode images to a fixed size vector
    """

    def __init__(
        self, model_name=CFG.model_name, pretrained=CFG.pretrained, trainable=CFG.trainable
    ):
        super().__init__()
        self.model = timm.create_model(
            model_name, pretrained, num_classes=0, global_pool="avg"
        )
        for p in self.model.parameters():
            p.requires_grad = trainable

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ##8.3 Text Encoder

# %%
class TextEncoder(nn.Module):
    def __init__(self, model_name=CFG.text_encoder_model, pretrained=CFG.pretrained, trainable=CFG.trainable):
        super().__init__()
        if pretrained:
            self.model = DistilBertModel.from_pretrained(model_name)
        else:
            self.model = DistilBertModel(config=DistilBertConfig())
            
        for p in self.model.parameters():
            p.requires_grad = trainable

        # we are using the CLS token hidden representation as the sentence's embedding
        self.target_token_idx = 0

    def forward(self, input_ids, attention_mask):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = output.last_hidden_state
        return last_hidden_state[:, self.target_token_idx, :]

# %% [markdown]
# ##8.4 Projection Head

# %%
class ProjectionHead(nn.Module):
    def __init__(
        self,
        embedding_dim,
        projection_dim=CFG.projection_dim,
        dropout=CFG.dropout
    ):
        super().__init__()
        self.projection = nn.Linear(embedding_dim, projection_dim)
        self.gelu = nn.GELU()
        self.fc = nn.Linear(projection_dim, projection_dim)
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(projection_dim)
    
    def forward(self, x):
        projected = self.projection(x)
        x = self.gelu(projected)
        x = self.fc(x)
        x = self.dropout(x)
        x = x + projected
        x = self.layer_norm(x)
        return x

# %% [markdown]
# ##8.5 CLIP Model

# %%
class CLIPModel(nn.Module):
    def __init__(
        self,
        temperature=CFG.temperature,
        image_embedding=CFG.image_embedding,
        text_embedding=CFG.text_embedding,
    ):
        super().__init__()
        self.image_encoder = ImageEncoder()
        self.text_encoder = TextEncoder()
        self.image_projection = ProjectionHead(embedding_dim=image_embedding)
        self.text_projection = ProjectionHead(embedding_dim=text_embedding)
        self.temperature = temperature


    def forward(self, batch):
        # Getting Image and Text Features
        image_features = self.image_encoder(batch["image"])
        text_features = self.text_encoder(
            input_ids=batch["input_ids"], attention_mask=batch["attention_mask"]
        )

        # Getting Image and Text Embeddings (with same dimension)
        image_embeddings = self.image_projection(image_features)
        text_embeddings = self.text_projection(text_features)

        # Calculating the Loss
        logits = (text_embeddings @ image_embeddings.T) / self.temperature
        images_similarity = image_embeddings @ image_embeddings.T
        texts_similarity = text_embeddings @ text_embeddings.T
        targets = F.softmax(
            (images_similarity + texts_similarity) / (2 * self.temperature), dim=-1
        )
        texts_loss = cross_entropy(logits, targets, reduction='none')
        images_loss = cross_entropy(logits.T, targets.T, reduction='none')
        loss =  (images_loss + texts_loss) / 2.0 # shape: (batch_size)
        return loss.mean()

def cross_entropy(preds, targets, reduction='none'):
    log_softmax = nn.LogSoftmax(dim=-1)
    loss = (-targets * log_softmax(preds)).sum(1)
    if reduction == "none":
        return loss
    elif reduction == "mean":
        return loss.mean()

# %% [markdown]
# ##8.6 Training Components

# %%
def make_train_valid_dfs():
    dataframe = pd.read_csv(f"{CFG.captions_path}/captions.csv")
    max_id = dataframe["id"].max() + 1 if not CFG.debug else 100
    image_ids = np.arange(0, max_id)
    np.random.seed(42)
    valid_ids = np.random.choice(
        image_ids, size=int(0.2 * len(image_ids)), replace=False
    )
    train_ids = [id_ for id_ in image_ids if id_ not in valid_ids]
    train_dataframe = dataframe[dataframe["id"].isin(train_ids)].reset_index(drop=True)
    valid_dataframe = dataframe[dataframe["id"].isin(valid_ids)].reset_index(drop=True)
    return train_dataframe, valid_dataframe



def build_loaders(dataframe, tokenizer):
    image_paths = dataframe["image"].astype('str').tolist()
    texts = [" ".join(x) for x in dataframe.iloc[:, ~dataframe.columns.isin(['id', 'year', 'image'])].astype('str').values.tolist()]
    dataset = CLIP_Dataset(
        image_paths,
        texts,
        tokenizer=tokenizer
    )

    dataloader = torch.utils.data.DataLoader(
        dataset,
        batch_size=CFG.batch_size,
        num_workers=CFG.num_workers
    )
    return dataloader

# %%
def train_epoch(model, train_loader, optimizer, lr_scheduler, step):
    loss_meter = AvgMeter()
    tqdm_object = tqdm(train_loader, total=len(train_loader))
    # print(len(train_loader))
    for batch in tqdm_object:
        batch = {k: v.to(CFG.device) for k, v in batch.items() if k != "caption"}
        loss = model(batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if step == "batch":
            lr_scheduler.step()

        count = batch["image"].size(0)
        loss_meter.update(loss.item(), count)

        tqdm_object.set_postfix(train_loss=loss_meter.avg, lr=get_lr(optimizer))
    return loss_meter


def valid_epoch(model, valid_loader):
    loss_meter = AvgMeter()

    tqdm_object = tqdm(valid_loader, total=len(valid_loader))
    for batch in tqdm_object:
        batch = {k: v.to(CFG.device) for k, v in batch.items() if k != "caption"}
        loss = model(batch)

        count = batch["image"].size(0)
        loss_meter.update(loss.item(), count)

        tqdm_object.set_postfix(valid_loss=loss_meter.avg)
    return loss_meter


def main():
    train_df, valid_df = make_train_valid_dfs()
    tokenizer = DistilBertTokenizer.from_pretrained(CFG.text_tokenizer)

    train_loader = build_loaders(train_df, tokenizer)
    valid_loader = build_loaders(valid_df, tokenizer)


    model = CLIPModel().to(CFG.device)
    params = [
        {"params": model.image_encoder.parameters(), "lr": CFG.image_encoder_lr},
        {"params": model.text_encoder.parameters(), "lr": CFG.text_encoder_lr},
        {"params": itertools.chain(
            model.image_projection.parameters(), model.text_projection.parameters()
        ), "lr": CFG.head_lr, "weight_decay": CFG.weight_decay}
    ]


    optimizer = torch.optim.Adam(params,betas=(0.9, 0.95),eps=1e-6)
    lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", patience=CFG.patience, factor=CFG.factor
    )
    step = "epoch"

    best_loss = float('inf')
    for epoch in range(CFG.epochs):
        print(f"Epoch: {epoch + 1}")
        model.train()
        train_loss = train_epoch(model, train_loader, optimizer, lr_scheduler, step)
        model.eval()
        with torch.no_grad():
            valid_loss = valid_epoch(model, valid_loader)
        
        if valid_loss.avg < best_loss:
            best_loss = valid_loss.avg
            torch.save(model.state_dict(), "/content/drive/MyDrive/Saved_Model/OpenAI_CLIP_model_VIT_Fashion_Finetuned_with_aug_trial1.pt")
            print("Saved Best Model!")
        
        lr_scheduler.step(valid_loss.avg)

# %% [markdown]
# #9. Finetuning

# %%
main()
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Epoch: 1
#   0%|          | 0/557 [00:00<?, ?it/s]
# <ipython-input-16-17cb8e3104ba>:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['image'] = torch.tensor(image)
#   0%|          | 0/138 [00:00<?, ?it/s]
# Saved Best Model!
# Epoch: 2
#   0%|          | 0/557 [00:00<?, ?it/s]
#   0%|          | 0/138 [00:00<?, ?it/s]
# Saved Best Model!
# Epoch: 3
#   0%|          | 0/557 [00:00<?, ?it/s]
#   0%|          | 0/138 [00:00<?, ?it/s]
# Saved Best Model!
# Epoch: 4
#   0%|          | 0/557 [00:00<?, ?it/s]
#   0%|          | 0/138 [00:00<?, ?it/s]
# Saved Best Model!

# %% [markdown]
# #10. Inference

# %% [markdown]
# ### Getting Image Embeddings

# %%
def get_image_embeddings(valid_df, model_path):
    tokenizer = DistilBertTokenizer.from_pretrained(CFG.text_tokenizer)
    valid_loader = build_loaders(valid_df, tokenizer)
    
    model = CLIPModel().to(CFG.device)
    model.load_state_dict(torch.load(model_path, map_location=CFG.device))
    model.eval()
    
    valid_image_embeddings = []
    with torch.no_grad():
        for batch in tqdm(valid_loader):
            image_features = model.image_encoder(batch["image"].to(CFG.device))
            image_embeddings = model.image_projection(image_features)
            valid_image_embeddings.append(image_embeddings)
    return model, torch.cat(valid_image_embeddings)

# %%
_, valid_df = make_train_valid_dfs()
model, image_embeddings = get_image_embeddings(valid_df, "/content/drive/MyDrive/Saved_Model/OpenAI_CLIP_model_VIT_Fashion_Finetuned_with_aug_trial1.pt")
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_transform.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/138 [00:00<?, ?it/s]
# <ipython-input-16-17cb8e3104ba>:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['image'] = torch.tensor(image)

# %% [markdown]
# ### Finding Matches

# %% [markdown]
# This function does the final task that we wished our model would be capable of: it gets the model, image_embeddings, and a text query. It will display the most relevant images from the validation set! Isn't it amazing? Let's see how it performs after all!

# %%
def find_matches(model, image_embeddings, query, image_filenames, n=9):
    tokenizer = DistilBertTokenizer.from_pretrained(CFG.text_tokenizer)
    encoded_query = tokenizer([query])
    batch = {
        key: torch.tensor(values).to(CFG.device)
        for key, values in encoded_query.items()
    }
    with torch.no_grad():
        text_features = model.text_encoder(
            input_ids=batch["input_ids"], attention_mask=batch["attention_mask"]
        )
        text_embeddings = model.text_projection(text_features)
    
    image_embeddings_n = F.normalize(image_embeddings, p=2, dim=-1)
    text_embeddings_n = F.normalize(text_embeddings, p=2, dim=-1)
    dot_similarity = text_embeddings_n @ image_embeddings_n.T
    
    values, indices = torch.topk(dot_similarity.squeeze(0), n * 5)
    matches = [image_filenames[idx] for idx in indices[::5]]
    
    _, axes = plt.subplots(3, 3, figsize=(10, 10))
    for match, ax in zip(matches, axes.flatten()):
        image = cv2.imread(f"{CFG.image_path}/{match}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        ax.imshow(image)
        ax.axis("off")
    
    plt.show()

# %%
find_matches(model, 
             image_embeddings,
             query="red t-shirt for men",
             image_filenames=valid_df['image'].values,
             n=14)
